# %% [markdown]
# # Pre-processing ZIP all files in folder uploaded to JEDI
#
# The following notbooks set up to help raster-data-processing for the uploaded to JEDI
# https://jedi.discomap.eea.europa.eu/Search
#
# Requirements for raster upload to JEDI:
# - pixel sizes in (10m, 100, 1000m or 10 000m)
# - projection: LAEA -EPSG3035
# - datatype: INT8,UINT8,INT16 ant UINT16.
# - pixel nbit proberty:  NO nbits--> remove NBITS
# - Compression:  -co COMPRESS=JPEG -co TILED=YES
# - format: *.tif
#
#
# Every raster in the zip will be added as an attribute to the dimension.
# You can exclude values inside the JEDI website under the field options. Provide a value seperated list of all values you wish to exclude.
# The exclude will only work for INT8,UINT8,INT16 ant UINT16.
#
# So, there is a workaround in place:
# 1. Create a zip with the same tifs but these must be clipped to a small area.
# This way the uploaded zip is small but enough to populate the schema in the db.
# 2. When the dim is created (but not completed) send us the path to the real zip file and we will take care of it

# %%
# tool1 layerstack to single band
import os, sys 

from pathlib import Path
import os
import sys
from datetime import datetime
import multiprocessing
import glob
import logging
import zipfile
import shutil  ## for zipping


# set logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(message)s')
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
ch.setFormatter(formatter)
logger.addHandler(ch)

# set data folder
sys.path.append(Path(os.getcwd()).parent.joinpath('src').as_posix())
sys.path.append(Path(os.getcwd()).joinpath('src').as_posix())
from constants import dir_signature

###################################################################################################################################### SET



aoi_folder = r'M:\f01_dims\gdmp\gdmp_1km_statistics\aoi'
zip_folder = r'M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi'



# To allow overwriting outputs change overwriteOutput option to True.

###################################################################################################################################### SET
print ("START.................")
####################################################################



input_folder=aoi_folder
with os.scandir(input_folder) as p:
    for raster in p:

        if  raster.name.endswith(".tif"): # Only show the files whose name ends with dot tif.
            raster_file = os.path.join(input_folder, raster.name) # Get the full path of the raster, you'll need it in order to open the raster file and access its data. 
            #raster = gdal.Open(raster_file) # Open the current raster file.
            raster_name = os.path.join(raster.name)

            archive_name =zip_folder+"\\"+raster_name.rsplit('_', maxsplit=1)[0]+'.zip'
            print (raster)
            print (archive_name)
            raster_new_name = raster_name.rsplit('_', maxsplit=1)[0]+'.tif'

            with zipfile.ZipFile(archive_name, 'w') as file:
                file.write(raster, arcname=raster_new_name)


print ("done")
# Out:
# START.................
# <DirEntry 'GDMP_1km_anom_1999_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_1999.zip
# <DirEntry 'GDMP_1km_anom_2000_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2000.zip
# <DirEntry 'GDMP_1km_anom_2001_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2001.zip
# <DirEntry 'GDMP_1km_anom_2002_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2002.zip
# <DirEntry 'GDMP_1km_anom_2003_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2003.zip
# <DirEntry 'GDMP_1km_anom_2004_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2004.zip
# <DirEntry 'GDMP_1km_anom_2005_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2005.zip
# <DirEntry 'GDMP_1km_anom_2006_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2006.zip
# <DirEntry 'GDMP_1km_anom_2007_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2007.zip
# <DirEntry 'GDMP_1km_anom_2008_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2008.zip
# <DirEntry 'GDMP_1km_anom_2009_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2009.zip
# <DirEntry 'GDMP_1km_anom_2010_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2010.zip
# <DirEntry 'GDMP_1km_anom_2011_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2011.zip
# <DirEntry 'GDMP_1km_anom_2012_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2012.zip
# <DirEntry 'GDMP_1km_anom_2013_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2013.zip
# <DirEntry 'GDMP_1km_anom_2014_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2014.zip
# <DirEntry 'GDMP_1km_anom_2015_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2015.zip
# <DirEntry 'GDMP_1km_anom_2016_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2016.zip
# <DirEntry 'GDMP_1km_anom_2017_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2017.zip
# <DirEntry 'GDMP_1km_anom_2018_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2018.zip
# <DirEntry 'GDMP_1km_anom_2019_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2019.zip
# <DirEntry 'GDMP_1km_anom_2020_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2020.zip
# <DirEntry 'GDMP_1km_anom_2021_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2021.zip
# <DirEntry 'GDMP_1km_anom_2022_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_anom_2022.zip
# <DirEntry 'GDMP_1km_deviation_1999_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_1999.zip
# <DirEntry 'GDMP_1km_deviation_2000_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2000.zip
# <DirEntry 'GDMP_1km_deviation_2001_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2001.zip
# <DirEntry 'GDMP_1km_deviation_2002_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2002.zip
# <DirEntry 'GDMP_1km_deviation_2003_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2003.zip
# <DirEntry 'GDMP_1km_deviation_2004_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2004.zip
# <DirEntry 'GDMP_1km_deviation_2005_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2005.zip
# <DirEntry 'GDMP_1km_deviation_2006_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2006.zip
# <DirEntry 'GDMP_1km_deviation_2007_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2007.zip
# <DirEntry 'GDMP_1km_deviation_2008_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2008.zip
# <DirEntry 'GDMP_1km_deviation_2009_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2009.zip
# <DirEntry 'GDMP_1km_deviation_2010_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2010.zip
# <DirEntry 'GDMP_1km_deviation_2011_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2011.zip
# <DirEntry 'GDMP_1km_deviation_2012_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2012.zip
# <DirEntry 'GDMP_1km_deviation_2013_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2013.zip
# <DirEntry 'GDMP_1km_deviation_2014_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2014.zip
# <DirEntry 'GDMP_1km_deviation_2015_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2015.zip
# <DirEntry 'GDMP_1km_deviation_2016_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2016.zip
# <DirEntry 'GDMP_1km_deviation_2017_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2017.zip
# <DirEntry 'GDMP_1km_deviation_2018_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2018.zip
# <DirEntry 'GDMP_1km_deviation_2019_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2019.zip
# <DirEntry 'GDMP_1km_deviation_2020_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2020.zip
# <DirEntry 'GDMP_1km_deviation_2021_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2021.zip
# <DirEntry 'GDMP_1km_deviation_2022_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_deviation_2022.zip
# <DirEntry 'GDMP_1km_mean_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_mean.zip
# <DirEntry 'GDMP_1km_pvalue_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_pvalue.zip
# <DirEntry 'GDMP_1km_slope_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_slope.zip
# <DirEntry 'GDMP_1km_std_tif.tif'>
# M:\f01_dims\gdmp\gdmp_1km_statistics\zip\aoi\GDMP_1km_std.zip
# done

# %%
print (raster_name)
# Out:
# GDMP_1km_std_tif.tif
